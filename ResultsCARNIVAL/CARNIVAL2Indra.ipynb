# %%
import indra

# %%
from indra.sources import trips
from indra.assemblers.pysb import PysbAssembler
from indra.sources import bel
from indra.assemblers.sif import SifAssembler
from indra.assemblers.cag.assembler import CAGAssembler
from indra.assemblers.sbgn.assembler import SBGNAssembler
from indra.assemblers.indranet.assembler import IndraNetAssembler
from indra.assemblers.pybel.assembler import PybelAssembler

# %% [markdown]
# * Additional hypotheses beyond CARNIVAL
#     * Priming hypothesis
#     * MaxEnt hypothesis
#     * InvCARNIVAL (no perturbations)
#     * CARNIVAL (with perturbations)
# * Developing strategies for actionable interventions of CARNIVAL output
#    * Minimal change
#    * Identifying druggable targets of the CARNIVAL outputs
#    * Adverse effects of druggable targets
# *	Identifying additional sources of knowledge that can be used to identify viral-host protein interactions as inputs to CARNIVAL
# *	Generating evidence and visualizations that support the CARNIVAL outputs using dialogue.bio and pathwaymap.indra.bio
# *	Curating the CARNIVAL output to add potential confounders
# *	Curating the CARNIVAL output to discover feedback loops
# *	Identifying and curating the molecular signatures of the CARNIVAL inputs
# *	Analyzing similarities and differences in CARNIVAL outputs as a function of time
# *	Analyzing similarities and differences in CARNIVAL outputs as a function of viral strain
# * Extract molecular signature for double-circle nodes from Progeny/Dorothea

# %% [markdown]
# January goal:
# * Demonstrate we can interrogate a model of Influenza pathogenesis using PNNL Pan-viral multiomics datasets.
#     * Examples of types of questions one can ask of the model
#         * What is the effect of the treatment on the treated?
#         * What are the necessary causes of an effect?
#         * What are sufficient causes of an effect?
#         * What interventions could restore homeostasis?
#     * Hypotheses that would generate different models:
#         * Priming hypothesis
#         * MaxEnt hypothesis
#         * InvCARNIVAL (no perturbations)
#         * CARNIVAL (with perturbations)
#     * How does this compare with what is known?
#         * Is this surprising?
#             * If so, is it wrong?
#             * If not, is it new?
#     * What are limitations of model and how we would handle these threats to validity?
#         * Unobserved confounders
#         * Feedback loops
#         * Missing data
#         * Selection bias
#         * Transportability
#     * What experiments can improve the predictions or reduce uncertainty in the specification of the model?
#     * Suggestions that narrow down experimental space
#     * Proof that experiments reduce space
#     * Actionable suggestions that improve output.
#     * Confidence that additional experiments improve process
# * Data comparisons that could answer interesting questions:
#     * CARNIVAL output with and without known interactions
#     * diff between virus and mock
#     * diff between high-risk and low-risk virus
#     * diff between early and late infection
# * Ways to compare graphs--talk to Joseph

# %% [markdown]
# # Convert CARNIVAL output SIF into INDRA using REACH

# %%
with open('bob.txt') as bob:
    statements = bob.read().replace('\n', '. ')
    
    trips_processor = trips.process_text(statements)
        # Collect extracted mechanisms in PysbAssembler

# %%
assemblers = dict(
    sif = SifAssembler( trips_processor.statements ),
    cag = CAGAssembler(  trips_processor.statements ),
    sbgn = SBGNAssembler(  trips_processor.statements ),
    indranet = IndraNetAssembler(  trips_processor.statements ),
    pybel = PybelAssembler( trips_processor.statements ),
    pysb = PysbAssembler(trips_processor.statements)

)

model = {}
for a in assemblers:
    model[a] = assemblers[a].make_model()
# Out:
# INFO: [2020-11-18 14:10:09] indra.assemblers.pysb.assembler - Using default assembly policy.

# %%
print(assemblers['sif'].print_boolean_net())
# Out:
# MAPK14 = False
# STAT3 = False
# ATF2 = False
# AR = False
# HBP1 = False
# MEF2B = False
# MAPK3 = False
# SMAD2 = False
# PARP1 = False
# SREBF1 = False
# AKT1 = False
# MAP3K1 = False
# MTA1 = False
# BCL11A = False
# ZEB2 = False
# E2F4 = False
# MMP9 = False
# ATF3 = False
# ZEB1 = False
# NR4A1 = False
# NR0B2 = False
# NR5A2 = False
# NR2F2 = False
# ADCYAP1 = False
# FHL5 = False
# CREM = False
# PRKACA = False
# IRF3 = False
# FOS = False
# RARA = False
# CD44 = False
# TFAP2A = False
# E2F1 = False
# MYCN = False
# TP73 = False
# EGR1 = False
# MEF2C = False
# MAP2K4 = False
# MAPK11 = False
# PRKCD = False
# RB1 = False
# SP1 = False
# SP3 = False
# GSK3A = False
# TCF4 = False
# MEF2A = False
# MAX = False
# USF1 = False
# AURKB = False
# PRDM1 = False
# ZBED1 = False
# YAP1 = False
# TEAD1 = False
# KLF5 = False
# MNT = False
# TFAP4 = False
# POU2AF1 = False
# POU2F2 = False
# HMGB1 = False
# HOXD9 = False
# MEIS1 = False
# NANOG = False
# USF2 = False
# CDKL5 = False
# PBX2 = False
# TAF1 = False
# YY1 = False
# FBXO22 = False
# BACH1 = False
# PAX5 = False
# LIMS1 = False
# POU5F1 = False
# KDM5B = False
# KLF6 = False
# SNAI2 = False
# HOXB13 = False
# MYBL2 = False
# ZNF521 = False
# EBF1 = False
#
# MAPK14* = MAP3K1
# STAT3* = MAPK14 or MAPK3 or AKT1 or MAP3K1
# ATF2* = MAPK14 or MAPK3
# AR* = (MAPK14 or MAP3K1 or NR0B2) and not (E2F1 or EGR1 or TCF4)
# HBP1* = MAPK14
# MEF2B* = MAPK14
# MAPK3* = (AKT1 or MAP3K1 or ADCYAP1) and not (PRKCD)
# SMAD2* = MAPK3 or MAP3K1
# PARP1* = MAPK3
# SREBF1* = MAPK3 or AKT1
# AKT1* = not (LIMS1)
# MAP3K1* = AKT1
# MTA1* = AKT1
# BCL11A* = AKT1
# ZEB2* = SMAD2
# E2F4* = SMAD2
# MMP9* = STAT3
# ATF3* = ATF2
# ZEB1* = PARP1
# NR4A1* = MAP3K1
# NR0B2* = SREBF1
# NR5A2* = NR0B2
# NR2F2* = NR4A1
# CREM* = FHL5
# PRKACA* = AURKB or CDKL5
# IRF3* = PRKACA
# FOS* = PRKACA or MAPK11 or USF2
# RARA* = (PRKACA) and not (AKT1)
# CD44* = PRKACA
# TFAP2A* = PRKACA or MAPK11
# E2F1* = not (E2F4)
# MYCN* = E2F1
# TP73* = E2F1 or MAPK11 or YAP1 or PRKCD
# EGR1* = E2F1
# MEF2C* = E2F1 or RB1 or MAPK11
# MAP2K4* = not (AKT1)
# MAPK11* = MAP2K4
# PRKCD* = MAP2K4 or CDKL5
# RB1* = (AURKB) and not (MAPK14)
# SP1* = RB1 or MAPK11 or SP3 or TFAP4
# SP3* = RB1
# GSK3A* = not (AKT1)
# TCF4* = GSK3A
# MEF2A* = MAPK11
# MAX* = MAPK11
# USF1* = MAPK11
# AURKB* = not (PARP1)
# PRDM1* = AURKB
# ZBED1* = AURKB or CDKL5
# YAP1* = not (AKT1)
# TEAD1* = YAP1
# KLF5* = PRKCD
# MNT* = MAX
# POU2F2* = POU2AF1
# HMGB1* = not (ADCYAP1)
# HOXD9* = HMGB1
# MEIS1* = HOXD9
# NANOG* = CD44
# USF2* = not (NR2F2)
# PBX2* = CDKL5
# TAF1* = not (RB1)
# YY1* = not (RB1)
# BACH1* = not (FBXO22)
# PAX5* = not (PRDM1)
# POU5F1* = not (MAPK3)
# KDM5B* = not (PARP1)
# KLF6* = not (ATF3)
# SNAI2* = not (MMP9)
# HOXB13* = not (YY1)
# MYBL2* = not (E2F4)
# EBF1* = not (ZNF521)

# %%
with open('VN1203_at_7h.sbgn','wb') as out:
    sbgn = assemblers['sbgn'].print_model()
    out.write(sbgn)

# %%
assemblers['sbgn'].print_model

# %%
model = assemblers['cag'].print_tsv(file_name='vn1203_7h.causal.tsv')

assemblers['cag'].make_model()

# %%
# !cat bob.boolean.net

# %%
for u, v, data in assemblers['pybel'].make_model().edges( data=True):
    print(f'{u} {data["relation"]} {v}' )
# Out:
# p(HGNC:6876 ! MAPK14) increases p(HGNC:11364 ! STAT3)
# p(HGNC:6876 ! MAPK14) increases p(HGNC:11364 ! STAT3)
# p(HGNC:6876 ! MAPK14) increases p(HGNC:784 ! ATF2)
# p(HGNC:6876 ! MAPK14) increases p(HGNC:784 ! ATF2)
# p(HGNC:6876 ! MAPK14) increases p(HGNC:644 ! AR)
# p(HGNC:6876 ! MAPK14) increases p(HGNC:644 ! AR)
# p(HGNC:6876 ! MAPK14) increases p(HGNC:23200 ! HBP1)
# p(HGNC:6876 ! MAPK14) increases p(HGNC:23200 ! HBP1)
# p(HGNC:6876 ! MAPK14) increases p(HGNC:6995 ! MEF2B)
# p(HGNC:6876 ! MAPK14) increases p(HGNC:6995 ! MEF2B)
# p(HGNC:6876 ! MAPK14) decreases p(HGNC:9884 ! RB1)
# p(HGNC:6876 ! MAPK14) decreases p(HGNC:9884 ! RB1)
# p(HGNC:11364 ! STAT3) increases p(HGNC:7176 ! MMP9)
# p(HGNC:11364 ! STAT3) increases p(HGNC:7176 ! MMP9)
# p(HGNC:784 ! ATF2) increases p(HGNC:785 ! ATF3)
# p(HGNC:784 ! ATF2) increases p(HGNC:785 ! ATF3)
# p(HGNC:6877 ! MAPK3) increases p(HGNC:6768 ! SMAD2)
# p(HGNC:6877 ! MAPK3) increases p(HGNC:6768 ! SMAD2)
# p(HGNC:6877 ! MAPK3) increases p(HGNC:11364 ! STAT3)
# p(HGNC:6877 ! MAPK3) increases p(HGNC:11364 ! STAT3)
# p(HGNC:6877 ! MAPK3) increases p(HGNC:784 ! ATF2)
# p(HGNC:6877 ! MAPK3) increases p(HGNC:784 ! ATF2)
# p(HGNC:6877 ! MAPK3) increases p(HGNC:270 ! PARP1)
# p(HGNC:6877 ! MAPK3) increases p(HGNC:270 ! PARP1)
# p(HGNC:6877 ! MAPK3) increases p(HGNC:11289 ! SREBF1)
# p(HGNC:6877 ! MAPK3) increases p(HGNC:11289 ! SREBF1)
# p(HGNC:6877 ! MAPK3) decreases p(HGNC:9221 ! POU5F1)
# p(HGNC:6877 ! MAPK3) decreases p(HGNC:9221 ! POU5F1)
# p(HGNC:6768 ! SMAD2) increases p(HGNC:14881 ! ZEB2)
# p(HGNC:6768 ! SMAD2) increases p(HGNC:14881 ! ZEB2)
# p(HGNC:6768 ! SMAD2) increases p(HGNC:3118 ! E2F4)
# p(HGNC:6768 ! SMAD2) increases p(HGNC:3118 ! E2F4)
# p(HGNC:270 ! PARP1) increases p(HGNC:11642 ! ZEB1)
# p(HGNC:270 ! PARP1) increases p(HGNC:11642 ! ZEB1)
# p(HGNC:270 ! PARP1) decreases p(HGNC:11390 ! AURKB)
# p(HGNC:270 ! PARP1) decreases p(HGNC:11390 ! AURKB)
# p(HGNC:270 ! PARP1) decreases p(HGNC:18039 ! KDM5B)
# p(HGNC:270 ! PARP1) decreases p(HGNC:18039 ! KDM5B)
# p(HGNC:11289 ! SREBF1) increases p(HGNC:7961 ! NR0B2)
# p(HGNC:11289 ! SREBF1) increases p(HGNC:7961 ! NR0B2)
# p(HGNC:391 ! AKT1) increases p(HGNC:6877 ! MAPK3)
# p(HGNC:391 ! AKT1) increases p(HGNC:6877 ! MAPK3)
# p(HGNC:391 ! AKT1) increases p(HGNC:11364 ! STAT3)
# p(HGNC:391 ! AKT1) increases p(HGNC:11364 ! STAT3)
# p(HGNC:391 ! AKT1) increases p(HGNC:6848 ! MAP3K1)
# p(HGNC:391 ! AKT1) increases p(HGNC:6848 ! MAP3K1)
# p(HGNC:391 ! AKT1) increases p(HGNC:7410 ! MTA1)
# p(HGNC:391 ! AKT1) increases p(HGNC:7410 ! MTA1)
# p(HGNC:391 ! AKT1) increases p(HGNC:11289 ! SREBF1)
# p(HGNC:391 ! AKT1) increases p(HGNC:11289 ! SREBF1)
# p(HGNC:391 ! AKT1) increases p(HGNC:13221 ! BCL11A)
# p(HGNC:391 ! AKT1) increases p(HGNC:13221 ! BCL11A)
# p(HGNC:391 ! AKT1) decreases p(HGNC:6844 ! MAP2K4)
# p(HGNC:391 ! AKT1) decreases p(HGNC:6844 ! MAP2K4)
# p(HGNC:391 ! AKT1) decreases p(HGNC:4616 ! GSK3A)
# p(HGNC:391 ! AKT1) decreases p(HGNC:4616 ! GSK3A)
# p(HGNC:391 ! AKT1) decreases p(HGNC:16262 ! YAP1)
# p(HGNC:391 ! AKT1) decreases p(HGNC:16262 ! YAP1)
# p(HGNC:391 ! AKT1) decreases p(HGNC:9864 ! RARA)
# p(HGNC:391 ! AKT1) decreases p(HGNC:9864 ! RARA)
# p(HGNC:6848 ! MAP3K1) increases p(HGNC:6876 ! MAPK14)
# p(HGNC:6848 ! MAP3K1) increases p(HGNC:6876 ! MAPK14)
# p(HGNC:6848 ! MAP3K1) increases p(HGNC:6877 ! MAPK3)
# p(HGNC:6848 ! MAP3K1) increases p(HGNC:6877 ! MAPK3)
# p(HGNC:6848 ! MAP3K1) increases p(HGNC:6768 ! SMAD2)
# p(HGNC:6848 ! MAP3K1) increases p(HGNC:6768 ! SMAD2)
# p(HGNC:6848 ! MAP3K1) increases p(HGNC:11364 ! STAT3)
# p(HGNC:6848 ! MAP3K1) increases p(HGNC:11364 ! STAT3)
# p(HGNC:6848 ! MAP3K1) increases p(HGNC:644 ! AR)
# p(HGNC:6848 ! MAP3K1) increases p(HGNC:644 ! AR)
# p(HGNC:6848 ! MAP3K1) increases p(HGNC:7980 ! NR4A1)
# p(HGNC:6848 ! MAP3K1) increases p(HGNC:7980 ! NR4A1)
# p(HGNC:3118 ! E2F4) decreases p(HGNC:3113 ! E2F1)
# p(HGNC:3118 ! E2F4) decreases p(HGNC:3113 ! E2F1)
# p(HGNC:3118 ! E2F4) decreases p(HGNC:7548 ! MYBL2)
# p(HGNC:3118 ! E2F4) decreases p(HGNC:7548 ! MYBL2)
# p(HGNC:7176 ! MMP9) decreases p(HGNC:11094 ! SNAI2)
# p(HGNC:7176 ! MMP9) decreases p(HGNC:11094 ! SNAI2)
# p(HGNC:785 ! ATF3) decreases p(HGNC:2235 ! KLF6)
# p(HGNC:785 ! ATF3) decreases p(HGNC:2235 ! KLF6)
# p(HGNC:7980 ! NR4A1) increases p(HGNC:7976 ! NR2F2)
# p(HGNC:7980 ! NR4A1) increases p(HGNC:7976 ! NR2F2)
# p(HGNC:7961 ! NR0B2) increases p(HGNC:644 ! AR)
# p(HGNC:7961 ! NR0B2) increases p(HGNC:644 ! AR)
# p(HGNC:7961 ! NR0B2) increases p(HGNC:7984 ! NR5A2)
# p(HGNC:7961 ! NR0B2) increases p(HGNC:7984 ! NR5A2)
# p(HGNC:7976 ! NR2F2) decreases p(HGNC:12594 ! USF2)
# p(HGNC:7976 ! NR2F2) decreases p(HGNC:12594 ! USF2)
# p(HGNC:241 ! ADCYAP1) increases p(HGNC:6877 ! MAPK3)
# p(HGNC:241 ! ADCYAP1) increases p(HGNC:6877 ! MAPK3)
# p(HGNC:241 ! ADCYAP1) decreases p(HGNC:4983 ! HMGB1)
# p(HGNC:241 ! ADCYAP1) decreases p(HGNC:4983 ! HMGB1)
# p(HGNC:17371 ! FHL5) increases p(HGNC:2352 ! CREM)
# p(HGNC:17371 ! FHL5) increases p(HGNC:2352 ! CREM)
# p(HGNC:9380 ! PRKACA) increases p(HGNC:6118 ! IRF3)
# p(HGNC:9380 ! PRKACA) increases p(HGNC:6118 ! IRF3)
# p(HGNC:9380 ! PRKACA) increases p(HGNC:3796 ! FOS)
# p(HGNC:9380 ! PRKACA) increases p(HGNC:3796 ! FOS)
# p(HGNC:9380 ! PRKACA) increases p(HGNC:9864 ! RARA)
# p(HGNC:9380 ! PRKACA) increases p(HGNC:9864 ! RARA)
# p(HGNC:9380 ! PRKACA) increases p(HGNC:1681 ! CD44)
# p(HGNC:9380 ! PRKACA) increases p(HGNC:1681 ! CD44)
# p(HGNC:9380 ! PRKACA) increases p(HGNC:11742 ! TFAP2A)
# p(HGNC:9380 ! PRKACA) increases p(HGNC:11742 ! TFAP2A)
# p(HGNC:1681 ! CD44) increases p(HGNC:20857 ! NANOG)
# p(HGNC:1681 ! CD44) increases p(HGNC:20857 ! NANOG)
# p(HGNC:3113 ! E2F1) increases p(HGNC:7559 ! MYCN)
# p(HGNC:3113 ! E2F1) increases p(HGNC:7559 ! MYCN)
# p(HGNC:3113 ! E2F1) increases p(HGNC:12003 ! TP73)
# p(HGNC:3113 ! E2F1) increases p(HGNC:12003 ! TP73)
# p(HGNC:3113 ! E2F1) increases p(HGNC:3238 ! EGR1)
# p(HGNC:3113 ! E2F1) increases p(HGNC:3238 ! EGR1)
# p(HGNC:3113 ! E2F1) increases p(HGNC:6996 ! MEF2C)
# p(HGNC:3113 ! E2F1) increases p(HGNC:6996 ! MEF2C)
# p(HGNC:3113 ! E2F1) decreases p(HGNC:644 ! AR)
# p(HGNC:3113 ! E2F1) decreases p(HGNC:644 ! AR)
# p(HGNC:3238 ! EGR1) decreases p(HGNC:644 ! AR)
# p(HGNC:3238 ! EGR1) decreases p(HGNC:644 ! AR)
# p(HGNC:6844 ! MAP2K4) increases p(HGNC:6873 ! MAPK11)
# p(HGNC:6844 ! MAP2K4) increases p(HGNC:6873 ! MAPK11)
# p(HGNC:6844 ! MAP2K4) increases p(HGNC:9399 ! PRKCD)
# p(HGNC:6844 ! MAP2K4) increases p(HGNC:9399 ! PRKCD)
# p(HGNC:6873 ! MAPK11) increases p(HGNC:12003 ! TP73)
# p(HGNC:6873 ! MAPK11) increases p(HGNC:12003 ! TP73)
# p(HGNC:6873 ! MAPK11) increases p(HGNC:11205 ! SP1)
# p(HGNC:6873 ! MAPK11) increases p(HGNC:11205 ! SP1)
# p(HGNC:6873 ! MAPK11) increases p(HGNC:3796 ! FOS)
# p(HGNC:6873 ! MAPK11) increases p(HGNC:3796 ! FOS)
# p(HGNC:6873 ! MAPK11) increases p(HGNC:6993 ! MEF2A)
# p(HGNC:6873 ! MAPK11) increases p(HGNC:6993 ! MEF2A)
# p(HGNC:6873 ! MAPK11) increases p(HGNC:6913 ! MAX)
# p(HGNC:6873 ! MAPK11) increases p(HGNC:6913 ! MAX)
# p(HGNC:6873 ! MAPK11) increases p(HGNC:6996 ! MEF2C)
# p(HGNC:6873 ! MAPK11) increases p(HGNC:6996 ! MEF2C)
# p(HGNC:6873 ! MAPK11) increases p(HGNC:12593 ! USF1)
# p(HGNC:6873 ! MAPK11) increases p(HGNC:12593 ! USF1)
# p(HGNC:6873 ! MAPK11) increases p(HGNC:11742 ! TFAP2A)
# p(HGNC:6873 ! MAPK11) increases p(HGNC:11742 ! TFAP2A)
# p(HGNC:9399 ! PRKCD) increases p(HGNC:12003 ! TP73)
# p(HGNC:9399 ! PRKCD) increases p(HGNC:12003 ! TP73)
# p(HGNC:9399 ! PRKCD) increases p(HGNC:6349 ! KLF5)
# p(HGNC:9399 ! PRKCD) increases p(HGNC:6349 ! KLF5)
# p(HGNC:9399 ! PRKCD) decreases p(HGNC:6877 ! MAPK3)
# p(HGNC:9399 ! PRKCD) decreases p(HGNC:6877 ! MAPK3)
# p(HGNC:9884 ! RB1) increases p(HGNC:11205 ! SP1)
# p(HGNC:9884 ! RB1) increases p(HGNC:11205 ! SP1)
# p(HGNC:9884 ! RB1) increases p(HGNC:11208 ! SP3)
# p(HGNC:9884 ! RB1) increases p(HGNC:11208 ! SP3)
# p(HGNC:9884 ! RB1) increases p(HGNC:6996 ! MEF2C)
# p(HGNC:9884 ! RB1) increases p(HGNC:6996 ! MEF2C)
# p(HGNC:9884 ! RB1) decreases p(HGNC:11535 ! TAF1)
# p(HGNC:9884 ! RB1) decreases p(HGNC:11535 ! TAF1)
# p(HGNC:9884 ! RB1) decreases p(HGNC:12856 ! YY1)
# p(HGNC:9884 ! RB1) decreases p(HGNC:12856 ! YY1)
# p(HGNC:11208 ! SP3) increases p(HGNC:11205 ! SP1)
# p(HGNC:11208 ! SP3) increases p(HGNC:11205 ! SP1)
# p(HGNC:4616 ! GSK3A) increases p(HGNC:11634 ! TCF4)
# p(HGNC:4616 ! GSK3A) increases p(HGNC:11634 ! TCF4)
# p(HGNC:11634 ! TCF4) decreases p(HGNC:644 ! AR)
# p(HGNC:11634 ! TCF4) decreases p(HGNC:644 ! AR)
# p(HGNC:6913 ! MAX) increases p(HGNC:7188 ! MNT)
# p(HGNC:6913 ! MAX) increases p(HGNC:7188 ! MNT)
# p(HGNC:11390 ! AURKB) increases p(HGNC:9380 ! PRKACA)
# p(HGNC:11390 ! AURKB) increases p(HGNC:9380 ! PRKACA)
# p(HGNC:11390 ! AURKB) increases p(HGNC:9884 ! RB1)
# p(HGNC:11390 ! AURKB) increases p(HGNC:9884 ! RB1)
# p(HGNC:11390 ! AURKB) increases p(HGNC:9346 ! PRDM1)
# p(HGNC:11390 ! AURKB) increases p(HGNC:9346 ! PRDM1)
# p(HGNC:11390 ! AURKB) increases p(HGNC:447 ! ZBED1)
# p(HGNC:11390 ! AURKB) increases p(HGNC:447 ! ZBED1)
# p(HGNC:9346 ! PRDM1) decreases p(HGNC:8619 ! PAX5)
# p(HGNC:9346 ! PRDM1) decreases p(HGNC:8619 ! PAX5)
# p(HGNC:16262 ! YAP1) increases p(HGNC:12003 ! TP73)
# p(HGNC:16262 ! YAP1) increases p(HGNC:12003 ! TP73)
# p(HGNC:16262 ! YAP1) increases p(HGNC:11714 ! TEAD1)
# p(HGNC:16262 ! YAP1) increases p(HGNC:11714 ! TEAD1)
# p(HGNC:11745 ! TFAP4) increases p(HGNC:11205 ! SP1)
# p(HGNC:11745 ! TFAP4) increases p(HGNC:11205 ! SP1)
# p(HGNC:9211 ! POU2AF1) increases p(HGNC:9213 ! POU2F2)
# p(HGNC:9211 ! POU2AF1) increases p(HGNC:9213 ! POU2F2)
# p(HGNC:4983 ! HMGB1) increases p(HGNC:5140 ! HOXD9)
# p(HGNC:4983 ! HMGB1) increases p(HGNC:5140 ! HOXD9)
# p(HGNC:5140 ! HOXD9) increases p(HGNC:7000 ! MEIS1)
# p(HGNC:5140 ! HOXD9) increases p(HGNC:7000 ! MEIS1)
# p(HGNC:12594 ! USF2) increases p(HGNC:3796 ! FOS)
# p(HGNC:12594 ! USF2) increases p(HGNC:3796 ! FOS)
# p(HGNC:11411 ! CDKL5) increases p(HGNC:9380 ! PRKACA)
# p(HGNC:11411 ! CDKL5) increases p(HGNC:9380 ! PRKACA)
# p(HGNC:11411 ! CDKL5) increases p(HGNC:9399 ! PRKCD)
# p(HGNC:11411 ! CDKL5) increases p(HGNC:9399 ! PRKCD)
# p(HGNC:11411 ! CDKL5) increases p(HGNC:8633 ! PBX2)
# p(HGNC:11411 ! CDKL5) increases p(HGNC:8633 ! PBX2)
# p(HGNC:11411 ! CDKL5) increases p(HGNC:447 ! ZBED1)
# p(HGNC:11411 ! CDKL5) increases p(HGNC:447 ! ZBED1)
# p(HGNC:12856 ! YY1) decreases p(HGNC:5112 ! HOXB13)
# p(HGNC:12856 ! YY1) decreases p(HGNC:5112 ! HOXB13)
# p(HGNC:13593 ! FBXO22) decreases p(HGNC:935 ! BACH1)
# p(HGNC:13593 ! FBXO22) decreases p(HGNC:935 ! BACH1)
# p(HGNC:6616 ! LIMS1) decreases p(HGNC:391 ! AKT1)
# p(HGNC:6616 ! LIMS1) decreases p(HGNC:391 ! AKT1)
# p(HGNC:24605 ! ZNF521) decreases p(HGNC:3126 ! EBF1)
# p(HGNC:24605 ! ZNF521) decreases p(HGNC:3126 ! EBF1)

# %%
sorted(node.as_bel() for node in belgraph)
# Out:
# ['p(HGNC:11094 ! SNAI2)',
#  'p(HGNC:11205 ! SP1)',
#  'p(HGNC:11208 ! SP3)',
#  'p(HGNC:11289 ! SREBF1)',
#  'p(HGNC:11364 ! STAT3)',
#  'p(HGNC:11390 ! AURKB)',
#  'p(HGNC:11411 ! CDKL5)',
#  'p(HGNC:11535 ! TAF1)',
#  'p(HGNC:11634 ! TCF4)',
#  'p(HGNC:11642 ! ZEB1)',
#  'p(HGNC:11714 ! TEAD1)',
#  'p(HGNC:11742 ! TFAP2A)',
#  'p(HGNC:11745 ! TFAP4)',
#  'p(HGNC:12003 ! TP73)',
#  'p(HGNC:12593 ! USF1)',
#  'p(HGNC:12594 ! USF2)',
#  'p(HGNC:12856 ! YY1)',
#  'p(HGNC:13221 ! BCL11A)',
#  'p(HGNC:13593 ! FBXO22)',
#  'p(HGNC:14881 ! ZEB2)',
#  'p(HGNC:16262 ! YAP1)',
#  'p(HGNC:1681 ! CD44)',
#  'p(HGNC:17371 ! FHL5)',
#  'p(HGNC:18039 ! KDM5B)',
#  'p(HGNC:20857 ! NANOG)',
#  'p(HGNC:2235 ! KLF6)',
#  'p(HGNC:23200 ! HBP1)',
#  'p(HGNC:2352 ! CREM)',
#  'p(HGNC:241 ! ADCYAP1)',
#  'p(HGNC:24605 ! ZNF521)',
#  'p(HGNC:270 ! PARP1)',
#  'p(HGNC:3113 ! E2F1)',
#  'p(HGNC:3118 ! E2F4)',
#  'p(HGNC:3126 ! EBF1)',
#  'p(HGNC:3238 ! EGR1)',
#  'p(HGNC:3796 ! FOS)',
#  'p(HGNC:391 ! AKT1)',
#  'p(HGNC:447 ! ZBED1)',
#  'p(HGNC:4616 ! GSK3A)',
#  'p(HGNC:4983 ! HMGB1)',
#  'p(HGNC:5112 ! HOXB13)',
#  'p(HGNC:5140 ! HOXD9)',
#  'p(HGNC:6118 ! IRF3)',
#  'p(HGNC:6349 ! KLF5)',
#  'p(HGNC:644 ! AR)',
#  'p(HGNC:6616 ! LIMS1)',
#  'p(HGNC:6768 ! SMAD2)',
#  'p(HGNC:6844 ! MAP2K4)',
#  'p(HGNC:6848 ! MAP3K1)',
#  'p(HGNC:6873 ! MAPK11)',
#  'p(HGNC:6876 ! MAPK14)',
#  'p(HGNC:6877 ! MAPK3)',
#  'p(HGNC:6913 ! MAX)',
#  'p(HGNC:6993 ! MEF2A)',
#  'p(HGNC:6995 ! MEF2B)',
#  'p(HGNC:6996 ! MEF2C)',
#  'p(HGNC:7000 ! MEIS1)',
#  'p(HGNC:7176 ! MMP9)',
#  'p(HGNC:7188 ! MNT)',
#  'p(HGNC:7410 ! MTA1)',
#  'p(HGNC:7548 ! MYBL2)',
#  'p(HGNC:7559 ! MYCN)',
#  'p(HGNC:784 ! ATF2)',
#  'p(HGNC:785 ! ATF3)',
#  'p(HGNC:7961 ! NR0B2)',
#  'p(HGNC:7976 ! NR2F2)',
#  'p(HGNC:7980 ! NR4A1)',
#  'p(HGNC:7984 ! NR5A2)',
#  'p(HGNC:8619 ! PAX5)',
#  'p(HGNC:8633 ! PBX2)',
#  'p(HGNC:9211 ! POU2AF1)',
#  'p(HGNC:9213 ! POU2F2)',
#  'p(HGNC:9221 ! POU5F1)',
#  'p(HGNC:9346 ! PRDM1)',
#  'p(HGNC:935 ! BACH1)',
#  'p(HGNC:9380 ! PRKACA)',
#  'p(HGNC:9399 ! PRKCD)',
#  'p(HGNC:9864 ! RARA)',
#  'p(HGNC:9884 ! RB1)']

# %%
# !grep  Perturbation bob.txt |wc -l
# Out:
#       12

# %% [markdown]
# ## Output statements from REACH
#
# It appears that at least one non-perturbation line did not get parsed

# %%
single_statement = trips.process_text('active PRKACA inhibits Active SREBF1. active MAPK14 activates active STAT3')
single_statement.statements
# Out:
# [Activation(MAPK14(activity), STAT3(activity)),
#  Inhibition(PRKACA(activity), SREBF1(activity))]

# %%
pb = PybelAssembler( single_statement.statements ).make_model()
sorted(node.as_bel() for node in pb)
# Out:
# ['p(HGNC:11289 ! SREBF1)',
#  'p(HGNC:11364 ! STAT3)',
#  'p(HGNC:6876 ! MAPK14)',
#  'p(HGNC:9380 ! PRKACA)']

# %%
pb.summarize()
# Out:
# indra v68774096-f5af-4ce6-82d8-83e9f6773a2f
# Number of Nodes: 4
# Number of Edges: 2
# Number of Citations: 1
# Number of Authors: 0
# Network Density: 1.67E-01
# Number of Components: 2
# Number of Warnings: 0

# %%
from pybel.io.jupyter import to_jupyter
to_jupyter(pb)

# %%
pa.make_model??

# %% [markdown]
# # Omnipath data

# %%
import pandas as pd
omnipath = pd.read_csv('OmnipathSignedDirectedInteractions.csv').drop_duplicates()#,index_col=['source_genesymbol','target_genesymbol'])
omnipath
# Out:
#                              source                        target  \
# 0                            P0DP24                        P48995
# 1                            Q03135                        P48995
# 2                            P14416                        P48995
# 3                            Q02790                        P48995
# 4                            Q99750                        P48995
# ...                             ...                           ...
# 60860                        O15264                        Q96BA8
# 60861  COMPLEX:P49023_Q05397_Q13418  COMPLEX:O43707_P18206_Q9Y4G6
# 60862  COMPLEX:P29466_Q96P20_Q9ULZ3                        P01584
# 67443                        P05129                        P00533
# 67446                        P05129                        P08581
#
#         source_genesymbol target_genesymbol  is_directed  is_stimulation  \
# 0                   CALM2             TRPC1            1               0
# 1                    CAV1             TRPC1            1               1
# 2                    DRD2             TRPC1            1               1
# 3                   FKBP4             TRPC1            1               0
# 4                    MDFI             TRPC1            1               0
# ...                   ...               ...          ...             ...
# 60860              MAPK13           CREB3L1            1               1
# 60861        ILK_PTK2_PXN    ACTN4_TLN2_VCL            1               1
# 60862  CASP1_NLRP3_PYCARD              IL1B            1               1
# 67443               PRKCG              EGFR            1               0
# 67446               PRKCG               MET            1               0
#
#        is_inhibition  consensus_direction  consensus_stimulation  \
# 0                  1                    1                      0
# 1                  0                    1                      1
# 2                  0                    1                      1
# 3                  1                    1                      0
# 4                  1                    1                      0
# ...              ...                  ...                    ...
# 60860              0                    1                      1
# 60861              0                    1                      1
# 60862              0                    1                      1
# 67443              1                    1                      0
# 67446              1                    1                      0
#
#        consensus_inhibition  \
# 0                         1
# 1                         0
# 2                         0
# 3                         1
# 4                         1
# ...                     ...
# 60860                     0
# 60861                     0
# 60862                     0
# 67443                     1
# 67446                     1
#
#                                                  dip_url  \
# 0                                                    NaN
# 1      http://dip.doe-mbi.ucla.edu/dip/DIPview.cgi?IK...
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 60860                                                NaN
# 60861                                                NaN
# 60862                                                NaN
# 67443                                                NaN
# 67446                                                NaN
#
#                                                  sources  \
# 0                                                   TRIP
# 1                         DIP;HPRD;IntAct;Lit-BM-17;TRIP
# 2                                                   TRIP
# 3                                                   TRIP
# 4                                              HPRD;TRIP
# ...                                                  ...
# 60860                                       KEGG-MEDICUS
# 60861                                       KEGG-MEDICUS
# 60862                                       KEGG-MEDICUS
# 67443  ACSN;HPRD_MIMP;MIMP;PhosphoSite_MIMP;phosphoEL...
# 67446  ACSN;HPRD_MIMP;MIMP;PhosphoSite_MIMP;phosphoEL...
#
#                                               references  curation_effort  \
# 0              TRIP:11290752;TRIP:11983166;TRIP:12601176                3
# 1      DIP:19897728;HPRD:12732636;IntAct:19897728;Lit...               13
# 2                                          TRIP:18261457                1
# 3              TRIP:15199065;TRIP:19945390;TRIP:23228564                3
# 4              HPRD:14530267;TRIP:14530267;TRIP:23770672                3
# ...                                                  ...              ...
# 60860                                                NaN                0
# 60861                                                NaN                0
# 60862                                                NaN                0
# 67443  ACSN:11313945;ACSN:11447289;ACSN:11940581;ACSN...               14
# 67446  ACSN:11313945;ACSN:11447289;ACSN:11940581;ACSN...               14
#
#        n_references  n_resources type
# 0                 3            1  ppi
# 1                 8            5  ppi
# 2                 1            1  ppi
# 3                 3            1  ppi
# 4                 2            2  ppi
# ...             ...          ...  ...
# 60860             0            1  ppi
# 60861             0            1  ppi
# 60862             0            1  ppi
# 67443            14            2  ppi
# 67446            14            2  ppi
#
# [51306 rows x 17 columns]

# %%
vn1203_7h = pd.read_excel('VN1203_at_7hr_CARNIVAL.xlsx',
                          sheet_name='RegulatoryInteractions')#.set_index(['Source','Target'])

vn1203_7h
# Out:
#            Source Relationship   Target
# 0          PRKACA     inhibits   SREBF1
# 1          MAPK14    activates    STAT3
# 2          MAPK14    activates     ATF2
# 3          MAPK14    activates       AR
# 4          MAPK14    activates     HBP1
# ..            ...          ...      ...
# 110  Perturbation    activates    LIMS1
# 111  Perturbation    activates     LYL1
# 112  Perturbation    activates  POU2AF1
# 113  Perturbation    activates      SP2
# 114  Perturbation    activates    TFAP4
#
# [115 rows x 3 columns]

# %%
vn1203_omnipath = pd.merge(vn1203_7h, omnipath, how='left',  left_on=['Source','Target'], 
         right_on=['source_genesymbol','target_genesymbol'])


vn1203_omnipath.to_excel('vn1203_omnipath.xlsx')
vn1203_omnipath
# Out:
#            Source Relationship   Target  source  target source_genesymbol  \
# 0          PRKACA     inhibits   SREBF1  P17612  P36956            PRKACA
# 1          MAPK14    activates    STAT3  Q16539  P40763            MAPK14
# 2          MAPK14    activates     ATF2  Q16539  P15336            MAPK14
# 3          MAPK14    activates       AR  Q16539  P10275            MAPK14
# 4          MAPK14    activates     HBP1  Q16539  O60381            MAPK14
# ..            ...          ...      ...     ...     ...               ...
# 110  Perturbation    activates    LIMS1     NaN     NaN               NaN
# 111  Perturbation    activates     LYL1     NaN     NaN               NaN
# 112  Perturbation    activates  POU2AF1     NaN     NaN               NaN
# 113  Perturbation    activates      SP2     NaN     NaN               NaN
# 114  Perturbation    activates    TFAP4     NaN     NaN               NaN
#
#     target_genesymbol  is_directed  is_stimulation  is_inhibition  \
# 0              SREBF1          1.0             0.0            1.0
# 1               STAT3          1.0             1.0            0.0
# 2                ATF2          1.0             1.0            0.0
# 3                  AR          1.0             1.0            0.0
# 4                HBP1          1.0             1.0            0.0
# ..                ...          ...             ...            ...
# 110               NaN          NaN             NaN            NaN
# 111               NaN          NaN             NaN            NaN
# 112               NaN          NaN             NaN            NaN
# 113               NaN          NaN             NaN            NaN
# 114               NaN          NaN             NaN            NaN
#
#      consensus_direction  consensus_stimulation  consensus_inhibition dip_url  \
# 0                    1.0                    0.0                   1.0     NaN
# 1                    1.0                    1.0                   0.0     NaN
# 2                    1.0                    1.0                   0.0     NaN
# 3                    1.0                    1.0                   0.0     NaN
# 4                    1.0                    1.0                   0.0     NaN
# ..                   ...                    ...                   ...     ...
# 110                  NaN                    NaN                   NaN     NaN
# 111                  NaN                    NaN                   NaN     NaN
# 112                  NaN                    NaN                   NaN     NaN
# 113                  NaN                    NaN                   NaN     NaN
# 114                  NaN                    NaN                   NaN     NaN
#
#                                                sources  \
# 0    MIMP;PhosphoSite;PhosphoSite_MIMP;PhosphoSite_...
# 1    HPRD_MIMP;KEA;MIMP;NCI-PID_ProtMapper;NetworKI...
# 2    ACSN;BEL-Large-Corpus_ProtMapper;BioGRID;CA1;C...
# 3    HPRD_MIMP;MIMP;NCI-PID_ProtMapper;PhosphoSite;...
# 4    MIMP;PhosphoSite;PhosphoSite_MIMP;PhosphoSite_...
# ..                                                 ...
# 110                                                NaN
# 111                                                NaN
# 112                                                NaN
# 113                                                NaN
# 114                                                NaN
#
#                                             references  curation_effort  \
# 0    PhosphoSite:16381800;ProtMapper:16381800;SIGNO...              4.0
# 1    KEA:17570479;ProtMapper:10201984;ProtMapper:17...             10.0
# 2    ACSN:11274345;ACSN:15140942;ACSN:15187187;ACSN...             99.0
# 3    PhosphoSite:16282370;ProtMapper:16282370;ProtM...              4.0
# 4    PhosphoSite:14612426;ProtMapper:14612426;SIGNO...              4.0
# ..                                                 ...              ...
# 110                                                NaN              NaN
# 111                                                NaN              NaN
# 112                                                NaN              NaN
# 113                                                NaN              NaN
# 114                                                NaN              NaN
#
#      n_references  n_resources type
# 0             1.0          5.0  ppi
# 1             5.0          7.0  ppi
# 2            58.0         20.0  ppi
# 3             3.0          4.0  ppi
# 4             1.0          5.0  ppi
# ..            ...          ...  ...
# 110           NaN          NaN  NaN
# 111           NaN          NaN  NaN
# 112           NaN          NaN  NaN
# 113           NaN          NaN  NaN
# 114           NaN          NaN  NaN
#
# [115 rows x 20 columns]

# %%
omnipath[(omnipath['source_genesymbol'] =='MAPK14') & (omnipath['target_genesymbol']== 'STAT3')]
# Out:
#        source  target source_genesymbol target_genesymbol  is_directed  \
# 3926   Q16539  P40763            MAPK14             STAT3            1
# 21847  Q16539  P40763            MAPK14             STAT3            1
# 61703  Q16539  P40763            MAPK14             STAT3            1
#
#        is_stimulation  is_inhibition  consensus_direction  \
# 3926                1              0                    1
# 21847               1              0                    1
# 61703               1              0                    1
#
#        consensus_stimulation  consensus_inhibition dip_url  \
# 3926                       1                     0     NaN
# 21847                      1                     0     NaN
# 61703                      1                     0     NaN
#
#                                                  sources  \
# 3926   HPRD_MIMP;KEA;MIMP;NCI-PID_ProtMapper;NetworKI...
# 21847  HPRD_MIMP;KEA;MIMP;NCI-PID_ProtMapper;NetworKI...
# 61703  HPRD_MIMP;KEA;MIMP;NCI-PID_ProtMapper;NetworKI...
#
#                                               references  curation_effort  \
# 3926   KEA:17570479;ProtMapper:10201984;ProtMapper:17...               10
# 21847  KEA:17570479;ProtMapper:10201984;ProtMapper:17...               10
# 61703  KEA:17570479;ProtMapper:10201984;ProtMapper:17...               10
#
#        n_references  n_resources type
# 3926              5            7  ppi
# 21847             5            7  ppi
# 61703             5            7  ppi

# %%
omnipath_idx = omnipath.set_index(['source_genesymbol','target_genesymbol'])
omnipath_idx.index = tuple(omnipath_idx.index)
omnipath_idx
# Out:
#                  source  target  is_directed  is_stimulation  is_inhibition  \
# CALM2  TRPC1     P0DP24  P48995            1               0              1
# CAV1   TRPC1     Q03135  P48995            1               1              0
# DRD2   TRPC1     P14416  P48995            1               1              0
# FKBP4  TRPC1     Q02790  P48995            1               0              1
# MDFI   TRPC1     Q99750  P48995            1               0              1
# ...                 ...     ...          ...             ...            ...
# ANP32B TNFRSF17  Q92688  Q02223            1               1              0
# CCL13  CCR10     Q99616  P46092            1               1              0
#        CCR4      Q99616  P51679            1               1              0
# INHBE  ACVR1     P58166  Q04771            1               1              0
#        ACVR1B    P58166  P36896            1               1              0
#
#                  consensus_direction  consensus_stimulation  \
# CALM2  TRPC1                       1                      0
# CAV1   TRPC1                       1                      1
# DRD2   TRPC1                       1                      1
# FKBP4  TRPC1                       1                      0
# MDFI   TRPC1                       1                      0
# ...                              ...                    ...
# ANP32B TNFRSF17                    1                      1
# CCL13  CCR10                       1                      1
#        CCR4                        1                      1
# INHBE  ACVR1                       1                      1
#        ACVR1B                      1                      1
#
#                  consensus_inhibition  \
# CALM2  TRPC1                        1
# CAV1   TRPC1                        0
# DRD2   TRPC1                        0
# FKBP4  TRPC1                        1
# MDFI   TRPC1                        1
# ...                               ...
# ANP32B TNFRSF17                     0
# CCL13  CCR10                        0
#        CCR4                         0
# INHBE  ACVR1                        0
#        ACVR1B                       0
#
#                                                            dip_url  \
# CALM2  TRPC1                                                   NaN
# CAV1   TRPC1     http://dip.doe-mbi.ucla.edu/dip/DIPview.cgi?IK...
# DRD2   TRPC1                                                   NaN
# FKBP4  TRPC1                                                   NaN
# MDFI   TRPC1                                                   NaN
# ...                                                            ...
# ANP32B TNFRSF17                                                NaN
# CCL13  CCR10                                                   NaN
#        CCR4                                                    NaN
# INHBE  ACVR1                                                   NaN
#        ACVR1B                                                  NaN
#
#                                         sources  \
# CALM2  TRPC1                               TRIP
# CAV1   TRPC1     DIP;HPRD;IntAct;Lit-BM-17;TRIP
# DRD2   TRPC1                               TRIP
# FKBP4  TRPC1                               TRIP
# MDFI   TRPC1                          HPRD;TRIP
# ...                                         ...
# ANP32B TNFRSF17                     Kirouac2010
# CCL13  CCR10                       EMBRACE;Wang
#        CCR4                        EMBRACE;Wang
# INHBE  ACVR1                 EMBRACE;Wang;iTALK
#        ACVR1B                EMBRACE;Wang;iTALK
#
#                                                         references  \
# CALM2  TRPC1             TRIP:11290752;TRIP:11983166;TRIP:12601176
# CAV1   TRPC1     DIP:19897728;HPRD:12732636;IntAct:19897728;Lit...
# DRD2   TRPC1                                         TRIP:18261457
# FKBP4  TRPC1             TRIP:15199065;TRIP:19945390;TRIP:23228564
# MDFI   TRPC1             HPRD:14530267;TRIP:14530267;TRIP:23770672
# ...                                                            ...
# ANP32B TNFRSF17                                                NaN
# CCL13  CCR10                                                   NaN
#        CCR4                                                    NaN
# INHBE  ACVR1                                                   NaN
#        ACVR1B                                                  NaN
#
#                  curation_effort  n_references  n_resources type
# CALM2  TRPC1                   3             3            1  ppi
# CAV1   TRPC1                  13             8            5  ppi
# DRD2   TRPC1                   1             1            1  ppi
# FKBP4  TRPC1                   3             3            1  ppi
# MDFI   TRPC1                   3             2            2  ppi
# ...                          ...           ...          ...  ...
# ANP32B TNFRSF17                0             0            1  ppi
# CCL13  CCR10                   0             0            2  ppi
#        CCR4                    0             0            2  ppi
# INHBE  ACVR1                   0             0            3  ppi
#        ACVR1B                  0             0            3  ppi
#
# [69067 rows x 15 columns]
